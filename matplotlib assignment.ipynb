# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
url='https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv'
df= pd.read_csv(url)
df.head(1)
# Out:
#    pclass  survived                           name     sex   age  sibsp  \
# 0     1.0       1.0  Allen, Miss. Elisabeth Walton  female  29.0    0.0
#
#    parch ticket      fare cabin embarked boat  body     home.dest
# 0    0.0  24160  211.3375    B5        S    2   NaN  St Louis, MO

# %%
# 1. Create a pie chart presenting the male/female proportion
a=df['sex'].value_counts().values

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(10,8))
plt.pie(a,labels=['male','female'],autopct='%.2f',explode=[0,0.1],wedgeprops={'edgecolor':'black'},shadow=True)
plt.title('PIE CHART OF GENDER')
# Out:
# Text(0.5, 1.0, 'PIE CHART OF GENDER')

# %%
# 2. Create a scatterplot with the Fare paid and the Age, differ the plot color by gender
plt.figure(figsize=(15,8))
sns.scatterplot('age','fare',data=df,hue='sex')
plt.title('SCATTER PLOT OF AGE Vs FARE')
plt.tight_layout()
plt.show()
